# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
from sportsreference.nba.teams import Teams
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# MIL                  0.742         1159  ...     2     480
# HOU                  0.787         1310  ...     3     541
# POR                  0.798         1145  ...     4     401
# ATL                  0.790         1237  ...     5     523
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                            2779                              0.369
# MIL                            2510                              0.356
# HOU                            2832                              0.348
# POR                            2228                              0.372
# ATL                            2416                              0.333
#
#      three_point_field_goals  total_rebounds  turnovers  \
# DAL                     1026            3150        857
# MIL                      893            3362        969
# HOU                      986            2875        939
# POR                      829            3001        858
# ATL                      805            2898       1086
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# DAL                           3248                            0.542
# MIL                           3418                            0.567
# HOU                           2971                            0.554
# POR                           3770                            0.513
# ATL                           3651                            0.525
#
#      two_point_field_goals
# DAL                   1761
# MIL                   1937
# HOU                   1646
# POR                   1934
# ATL                   1918
#
# [5 rows x 47 columns]

# %%
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# GSW                  0.801         1339  ...     2     625
# NOP                  0.761         1462  ...     3     610
# PHI                  0.771         1742  ...     4     606
# LAC                  0.792         1853  ...     5     561
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# MIL                            3134                              0.353
# GSW                            2824                              0.385
# NOP                            2449                              0.344
# PHI                            2474                              0.359
# LAC                            2118                              0.388
#
#      three_point_field_goals  total_rebounds  turnovers  \
# MIL                     1105            4078       1137
# GSW                     1087            3787       1169
# NOP                      842            3878       1215
# PHI                      889            3917       1223
# LAC                      821            3732       1193
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# MIL                           4337                            0.565
# GSW                           4537                            0.557
# NOP                           5114                            0.536
# PHI                           4759                            0.529
# LAC                           5060                            0.507
#
#      two_point_field_goals
# MIL                   2450
# GSW                   2525
# NOP                   2739
# PHI                   2518
# LAC                   2563
#
# [5 rows x 47 columns]

# %%
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# HOU                  0.781         1609  ...     2     699
# NOP                  0.772         1324  ...     3     657
# TOR                  0.794         1422  ...     4     626
# CLE                  0.779         1488  ...     5     582
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# GSW                            2370                              0.391
# HOU                            3470                              0.362
# NOP                            2312                              0.362
# TOR                            2705                              0.358
# CLE                            2636                              0.372
#
#      three_point_field_goals  total_rebounds  turnovers  \
# GSW                      926            3568       1267
# HOU                     1256            3564       1135
# NOP                      837            3636       1223
# TOR                      968            3607       1095
# CLE                      981            3455       1126
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# GSW                           4611                            0.560
# HOU                           3436                            0.558
# NOP                           4929                            0.540
# TOR                           4464                            0.541
# CLE                           4314                            0.540
#
#      two_point_field_goals
# GSW                   2583
# HOU                   1918
# NOP                   2663
# TOR                   2415
# CLE                   2330
#
# [5 rows x 47 columns]

# %%
wins_17_18 = pd.read_csv('Data/team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
wins_18_19 = pd.read_csv('Data/team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
wins_19_20 = pd.read_csv('Data/team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20 = stats_19_20.assign(Season=['2019-2020'] * 30)
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1196  ...                             2779
# 1                  0.742         1159  ...                             2510
# 2                  0.787         1310  ...                             2832
# 3                  0.798         1145  ...                             2228
# 4                  0.790         1237  ...                             2416
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.369                    1026            3150
# 1                              0.356                     893            3362
# 2                              0.348                     986            2875
# 3                              0.372                     829            3001
# 4                              0.333                     805            2898
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0        857                           3248                            0.542
# 1        969                           3418                            0.567
# 2        939                           2971                            0.554
# 3        858                           3770                            0.513
# 4       1086                           3651                            0.525
#
#    two_point_field_goals   W     Season
# 0                   1761  40  2019-2020
# 1                   1937  53  2019-2020
# 2                   1646  40  2019-2020
# 3                   1934  29  2019-2020
# 4                   1918  20  2019-2020
#
# [5 rows x 49 columns]

# %%
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19 = stats_18_19.assign(Season=['2018-2019'] * 30)
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1471  ...                             3134
# 1                  0.801         1339  ...                             2824
# 2                  0.761         1462  ...                             2449
# 3                  0.771         1742  ...                             2474
# 4                  0.792         1853  ...                             2118
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.353                    1105            4078
# 1                              0.385                    1087            3787
# 2                              0.344                     842            3878
# 3                              0.359                     889            3917
# 4                              0.388                     821            3732
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1137                           4337                            0.565
# 1       1169                           4537                            0.557
# 2       1215                           5114                            0.536
# 3       1223                           4759                            0.529
# 4       1193                           5060                            0.507
#
#    two_point_field_goals   W     Season
# 0                   2450  60  2018-2019
# 1                   2525  57  2018-2019
# 2                   2739  33  2018-2019
# 3                   2518  51  2018-2019
# 4                   2563  48  2018-2019
#
# [5 rows x 49 columns]

# %%
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18 = stats_17_18.assign(Season=['2017-2018'] * 30)
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (90, 16) (90, 1)

# %%
# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_test
# Out:
#                         assists  defensive_rebounds  field_goal_percentage  \
# abbreviation Season
# GSW          2018-2019     2413                2990                  0.491
# BOS          2019-2020     1459                2259                  0.459
# ORL          2017-2018     1921                2692                  0.452
# MIN          2018-2019     2018                2750                  0.456
# CLE          2018-2019     1698                2619                  0.444
# MEM          2018-2019     1963                2703                  0.450
# SAC          2019-2020     1497                2104                  0.459
# NOP          2018-2019     2216                2969                  0.473
# CHI          2017-2018     1923                2873                  0.435
# PHI          2017-2018     2221                2996                  0.472
# IND          2018-2019     2128                2766                  0.475
# LAL          2018-2019     2096                2985                  0.470
# NOP          2017-2018     2195                2924                  0.483
# MEM          2019-2020     1757                2357                  0.470
# SAC          2018-2019     2083                2819                  0.464
# SAS          2018-2019     2013                2910                  0.478
# ATL          2017-2018     1946                2693                  0.446
# DEN          2017-2018     2059                2748                  0.470
# CHI          2019-2020     1510                2041                  0.447
# POR          2017-2018     1599                2893                  0.452
# LAC          2018-2019     1970                2936                  0.471
# BRK          2017-2018     1941                2852                  0.441
# ORL          2018-2019     2095                2902                  0.454
#
#                         field_goals  opp_assists  opp_blocks  \
# abbreviation Season
# GSW          2018-2019         3612         1989         295
# BOS          2019-2020         2634         1420         356
# ORL          2017-2018         3182         1998         402
# MIN          2018-2019         3413         2145         455
# CLE          2018-2019         3189         2107         459
# MEM          2018-2019         3113         1920         402
# SAC          2019-2020         2583         1570         278
# NOP          2018-2019         3581         2174         445
# CHI          2017-2018         3170         2123         423
# PHI          2017-2018         3349         1782         417
# IND          2018-2019         3390         2006         425
# LAL          2018-2019         3491         2053         421
# NOP          2017-2018         3500         1947         344
# MEM          2019-2020         2779         1615         347
# SAC          2018-2019         3541         2024         420
# SAS          2018-2019         3468         2025         332
# ATL          2017-2018         3130         2137         453
# DEN          2017-2018         3338         2028         391
# CHI          2019-2020         2573         1653         384
# POR          2017-2018         3222         1655         418
# LAC          2018-2019         3384         1976         498
# BRK          2017-2018         3136         1782         450
# ORL          2018-2019         3316         1892         362
#
#                         opp_defensive_rebounds  opp_field_goal_percentage  \
# abbreviation Season
# GSW          2018-2019                    2750                      0.444
# BOS          2019-2020                    2179                      0.442
# ORL          2017-2018                    2892                      0.468
# MIN          2018-2019                    2822                      0.467
# CLE          2018-2019                    2835                      0.495
# MEM          2018-2019                    2883                      0.451
# SAC          2019-2020                    2207                      0.468
# NOP          2018-2019                    2855                      0.466
# CHI          2017-2018                    3053                      0.472
# PHI          2017-2018                    2641                      0.434
# IND          2018-2019                    2718                      0.450
# LAL          2018-2019                    2918                      0.452
# NOP          2017-2018                    2843                      0.454
# MEM          2019-2020                    2242                      0.450
# SAC          2018-2019                    3015                      0.466
# SAS          2018-2019                    2844                      0.463
# ATL          2017-2018                    2785                      0.469
# DEN          2017-2018                    2613                      0.476
# CHI          2019-2020                    2299                      0.479
# POR          2017-2018                    2755                      0.447
# LAC          2018-2019                    2826                      0.457
# BRK          2017-2018                    2981                      0.466
# ORL          2018-2019                    2922                      0.456
#
#                         opp_points  opp_three_point_field_goal_percentage  \
# abbreviation Season
# GSW          2018-2019        9120                                  0.347
# BOS          2019-2020        6837                                  0.342
# ORL          2017-2018        8874                                  0.362
# MIN          2018-2019        9346                                  0.378
# CLE          2018-2019        9355                                  0.380
# MEM          2018-2019        8703                                  0.360
# SAC          2019-2020        7098                                  0.355
# NOP          2018-2019        9575                                  0.364
# CHI          2017-2018        9017                                  0.370
# PHI          2017-2018        8635                                  0.342
# IND          2018-2019        8584                                  0.354
# LAL          2018-2019        9306                                  0.349
# NOP          2017-2018        9054                                  0.355
# MEM          2019-2020        7391                                  0.363
# SAC          2018-2019        9455                                  0.348
# SAS          2018-2019        9018                                  0.359
# ATL          2017-2018        8922                                  0.377
# DEN          2017-2018        8899                                  0.378
# CHI          2019-2020        7145                                  0.353
# POR          2017-2018        8448                                  0.364
# LAC          2018-2019        9372                                  0.343
# BRK          2017-2018        9048                                  0.369
# ORL          2018-2019        8742                                  0.347
#
#                         opp_total_rebounds  \
# abbreviation Season
# GSW          2018-2019                3636
# BOS          2019-2020                2834
# ORL          2017-2018                3760
# MIN          2018-2019                3743
# CLE          2018-2019                3617
# MEM          2018-2019                3664
# SAC          2019-2020                2783
# NOP          2018-2019                3753
# CHI          2017-2018                3744
# PHI          2017-2018                3459
# IND          2018-2019                3580
# LAL          2018-2019                3842
# NOP          2017-2018                3730
# MEM          2019-2020                2922
# SAC          2018-2019                3932
# SAS          2018-2019                3600
# ATL          2017-2018                3626
# DEN          2017-2018                3413
# CHI          2019-2020                2959
# POR          2017-2018                3518
# LAC          2018-2019                3751
# BRK          2017-2018                3834
# ORL          2018-2019                3661
#
#                         opp_two_point_field_goal_percentage  points  \
# abbreviation Season
# GSW          2018-2019                                0.500    9650
# BOS          2019-2020                                0.507    7232
# ORL          2017-2018                                0.516    8479
# MIN          2018-2019                                0.520    9223
# CLE          2018-2019                                0.561    8567
# MEM          2018-2019                                0.508    8490
# SAC          2019-2020                                0.545    6975
# NOP          2018-2019                                0.525    9466
# CHI          2017-2018                                0.534    8440
# PHI          2017-2018                                0.482    9004
# IND          2018-2019                                0.507    8857
# LAL          2018-2019                                0.511    9165
# NOP          2017-2018                                0.503    9161
# MEM          2019-2020                                0.505    7321
# SAC          2018-2019                                0.540    9363
# SAS          2018-2019                                0.522    9156
# ATL          2017-2018                                0.520    8475
# DEN          2017-2018                                0.525    9020
# CHI          2019-2020                                0.557    6945
# POR          2017-2018                                0.484    8661
# LAC          2018-2019                                0.513    9442
# BRK          2017-2018                                0.503    8741
# ORL          2018-2019                                0.513    8800
#
#                         three_point_field_goal_percentage  total_rebounds  \
# abbreviation Season
# GSW          2018-2019                              0.385            3787
# BOS          2019-2020                              0.363            2942
# ORL          2017-2018                              0.351            3414
# MIN          2018-2019                              0.351            3673
# CLE          2018-2019                              0.355            3498
# MEM          2018-2019                              0.342            3426
# SAC          2019-2020                              0.364            2720
# NOP          2018-2019                              0.344            3878
# CHI          2017-2018                              0.355            3663
# PHI          2017-2018                              0.369            3889
# IND          2018-2019                              0.374            3528
# LAL          2018-2019                              0.333            3820
# NOP          2017-2018                              0.362            3636
# MEM          2019-2020                              0.352            3036
# SAC          2018-2019                              0.378            3725
# SAS          2018-2019                              0.392            3667
# ATL          2017-2018                              0.360            3436
# DEN          2017-2018                              0.371            3650
# CHI          2019-2020                              0.348            2721
# POR          2017-2018                              0.366            3728
# LAC          2018-2019                              0.388            3732
# BRK          2017-2018                              0.356            3644
# ORL          2018-2019                              0.356            3724
#
#                         two_point_field_goal_percentage
# abbreviation Season
# GSW          2018-2019                            0.557
# BOS          2019-2020                            0.519
# ORL          2017-2018                            0.504
# MIN          2018-2019                            0.504
# CLE          2018-2019                            0.488
# MEM          2018-2019                            0.505
# SAC          2019-2020                            0.522
# NOP          2018-2019                            0.536
# CHI          2017-2018                            0.478
# PHI          2017-2018                            0.526
# IND          2018-2019                            0.517
# LAL          2018-2019                            0.541
# NOP          2017-2018                            0.540
# MEM          2019-2020                            0.531
# SAC          2018-2019                            0.504
# SAS          2018-2019                            0.513
# ATL          2017-2018                            0.495
# DEN          2017-2018                            0.525
# CHI          2019-2020                            0.511
# POR          2017-2018                            0.493
# LAC          2018-2019                            0.507
# BRK          2017-2018                            0.500
# ORL          2018-2019                            0.509

# %%
# LASSO model

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error


lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)
predictions = predictions.flatten()

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

lasso_df = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True)

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lasso_df, how = 'left',left_index = True, right_index = True)

Lasso_Model_df = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
Lasso_Model_df
Lasso_Model_df.to_csv()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-eace9201794f> in <module>
#       7 lasso = Lasso(alpha=.01).fit(X_train, y_train)
#       8
# ----> 9 predictions = lasso.predict(X_test)
#      10 predictions = predictions.flatten()
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
#     884                                    dense_output=True) + self.intercept_
#     885         else:
# --> 886             return super()._decision_function(X)
#     887
#     888
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'GSW'

# %%
predictions = lasso.predict(X_test)
lasso.fit(X_train, y_train)
plt.scatter(lasso.predict(X_train), lasso.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
plt.scatter(lasso.predict(X_test), lasso.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7597ce5e2588> in <module>
# ----> 1 predictions = lasso.predict(X_test)
#       2 lasso.fit(X_train, y_train)
#       3 plt.scatter(lasso.predict(X_train), lasso.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
#       4 plt.scatter(lasso.predict(X_test), lasso.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
#       5 plt.legend()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
#     884                                    dense_output=True) + self.intercept_
#     885         else:
# --> 886             return super()._decision_function(X)
#     887
#     888
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'GSW'
