# %%
from sportsreference.nba.teams import Teams

teams = Teams("2019")

stats_19 = teams.dataframes

stats_19
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
# POR          POR     1887     413                2968                 7427
# OKC          OKC     1917     425                2911                 7706
# TOR          TOR     2085     437                2920                 7305
# SAC          SAC     2083     363                2819                 7637
# WAS          WAS     2154     379                2679                 7387
# HOU          HOU     1741     405                2613                 7163
# ...

# %%
stats_18 = Teams("2018").dataframes

stats_18
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
# DEN          DEN     2059     404                2748                 7102
# PHI          PHI     2221     420                2996                 7098
# MIN          MIN     1861     345                2593                 7063
# LAC          LAC     1832     373                2766                 7004
# CHO          CHO     1770     373                2901                 7106
# LAL          LAL     1949     388                2927                 7248
# ...

# %%
stats_17 = Teams("2017").dataframes

stats_17
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2491     555                2873                 7140
# HOU          HOU     2070     352                2746                 7152
# DEN          DEN     2077     323                2837                 7194
# CLE          CLE     1858     327                2821                 6963
# WAS          WAS     1956     336                2671                 7137
# LAC          LAC     1848     347                2790                 6820
# BOS          BOS     2069     340                2698                 6978
# POR          POR     1733     408                2750                 7059
# PHO          PHO     1604     399                2712                 7260
# TOR          TOR     1517     400                2676                 6918
# OKC          OKC     1721     408                2821                 7169
# ...
