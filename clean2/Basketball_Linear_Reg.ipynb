# %%
#Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sportsreference.nba.teams import Teams

# %%
#Importing stats from the 2019-2020 NBA Season *A full regular season was not played due to Covid-19*
# from sportsreference.nba.teams import Teams
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# MIL                  0.742         1159  ...     2     480
# HOU                  0.787         1310  ...     3     541
# POR                  0.798         1145  ...     4     401
# ATL                  0.790         1237  ...     5     523
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                            2779                              0.369
# MIL                            2510                              0.356
# HOU                            2832                              0.348
# POR                            2228                              0.372
# ATL                            2416                              0.333
#
#      three_point_field_goals  total_rebounds  turnovers  \
# DAL                     1026            3150        857
# MIL                      893            3362        969
# HOU                      986            2875        939
# POR                      829            3001        858
# ATL                      805            2898       1086
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# DAL                           3248                            0.542
# MIL                           3418                            0.567
# HOU                           2971                            0.554
# POR                           3770                            0.513
# ATL                           3651                            0.525
#
#      two_point_field_goals
# DAL                   1761
# MIL                   1937
# HOU                   1646
# POR                   1934
# ATL                   1918
#
# [5 rows x 47 columns]

# %%
#Importing stats from the 2018-2019 Season
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# GSW                  0.801         1339  ...     2     625
# NOP                  0.761         1462  ...     3     610
# PHI                  0.771         1742  ...     4     606
# LAC                  0.792         1853  ...     5     561
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# MIL                            3134                              0.353
# GSW                            2824                              0.385
# NOP                            2449                              0.344
# PHI                            2474                              0.359
# LAC                            2118                              0.388
#
#      three_point_field_goals  total_rebounds  turnovers  \
# MIL                     1105            4078       1137
# GSW                     1087            3787       1169
# NOP                      842            3878       1215
# PHI                      889            3917       1223
# LAC                      821            3732       1193
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# MIL                           4337                            0.565
# GSW                           4537                            0.557
# NOP                           5114                            0.536
# PHI                           4759                            0.529
# LAC                           5060                            0.507
#
#      two_point_field_goals
# MIL                   2450
# GSW                   2525
# NOP                   2739
# PHI                   2518
# LAC                   2563
#
# [5 rows x 47 columns]

# %%
#Importing stats from the 2017-2018 season
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# HOU                  0.781         1609  ...     2     699
# NOP                  0.772         1324  ...     3     657
# TOR                  0.794         1422  ...     4     626
# CLE                  0.779         1488  ...     5     582
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# GSW                            2370                              0.391
# HOU                            3470                              0.362
# NOP                            2312                              0.362
# TOR                            2705                              0.358
# CLE                            2636                              0.372
#
#      three_point_field_goals  total_rebounds  turnovers  \
# GSW                      926            3568       1267
# HOU                     1256            3564       1135
# NOP                      837            3636       1223
# TOR                      968            3607       1095
# CLE                      981            3455       1126
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# GSW                           4611                            0.560
# HOU                           3436                            0.558
# NOP                           4929                            0.540
# TOR                           4464                            0.541
# CLE                           4314                            0.540
#
#      two_point_field_goals
# GSW                   2583
# HOU                   1918
# NOP                   2663
# TOR                   2415
# CLE                   2330
#
# [5 rows x 47 columns]

# %%
#Importing team wins from the 2017-2018 Season
wins_17_18 = pd.read_csv('../Data/team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
#Importing team wins form the 2018-2019 season
wins_18_19 = pd.read_csv('../Data/team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
#Importing team wins from the 2019-2020 season
wins_19_20 = pd.read_csv('../Data/team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
#Merging team stats with team wins for 2019-2020
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20 = stats_19_20.assign(Season=['2019-2020'] * 30)
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1196  ...                             2779
# 1                  0.742         1159  ...                             2510
# 2                  0.787         1310  ...                             2832
# 3                  0.798         1145  ...                             2228
# 4                  0.790         1237  ...                             2416
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.369                    1026            3150
# 1                              0.356                     893            3362
# 2                              0.348                     986            2875
# 3                              0.372                     829            3001
# 4                              0.333                     805            2898
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0        857                           3248                            0.542
# 1        969                           3418                            0.567
# 2        939                           2971                            0.554
# 3        858                           3770                            0.513
# 4       1086                           3651                            0.525
#
#    two_point_field_goals   W     Season
# 0                   1761  40  2019-2020
# 1                   1937  53  2019-2020
# 2                   1646  40  2019-2020
# 3                   1934  29  2019-2020
# 4                   1918  20  2019-2020
#
# [5 rows x 49 columns]

# %%
#Merging team stats for the 2018-2019 season
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19 = stats_18_19.assign(Season=['2018-2019'] * 30)
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1471  ...                             3134
# 1                  0.801         1339  ...                             2824
# 2                  0.761         1462  ...                             2449
# 3                  0.771         1742  ...                             2474
# 4                  0.792         1853  ...                             2118
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.353                    1105            4078
# 1                              0.385                    1087            3787
# 2                              0.344                     842            3878
# 3                              0.359                     889            3917
# 4                              0.388                     821            3732
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1137                           4337                            0.565
# 1       1169                           4537                            0.557
# 2       1215                           5114                            0.536
# 3       1223                           4759                            0.529
# 4       1193                           5060                            0.507
#
#    two_point_field_goals   W     Season
# 0                   2450  60  2018-2019
# 1                   2525  57  2018-2019
# 2                   2739  33  2018-2019
# 3                   2518  51  2018-2019
# 4                   2563  48  2018-2019
#
# [5 rows x 49 columns]

# %%
#Mergin team stats for the 2017-2018 season
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18 = stats_17_18.assign(Season=['2017-2018'] * 30)
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
#Concatinating the stats into one dataframe
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
#all_df = read_csv("total_stats.csv")

# %%
# Assign the data to X and y

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
#Checking the shapes
print(X.shape, y.shape)
# Out:
# (90, 16) (90, 1)

# %%
# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
predictions = predictions.flatten()

#Printing the model MSE and Score for evaluation
MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")


lin_reg = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lin_reg, how = 'left',left_index = True, right_index = True)

linear_Model_df = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
linear_Model_df

#Writing the results to a csv and viewing the output 
linear_Model_df.to_csv('../Data/Linear_Model_Predictions.csv', index = False)

linear_Model_df
# Out:
# MSE: 11.81323897622613, R2: 0.8949042511448719
#        Season abbreviation  Prediction  Actual
# 0   2018-2019          BOS       53.98      49
# 1   2017-2018          NOP       46.55      48
# 2   2017-2018          MIL       38.26      44
# 3   2017-2018          LAC       40.47      42
# 4   2018-2019          DEN       51.02      54
# 5   2018-2019          CHO       39.09      39
# 6   2017-2018          TOR       59.28      59
# 7   2018-2019          MIN       37.51      36
# 8   2019-2020          PHI       36.87      39
# 9   2018-2019          POR       54.24      53
# 10  2018-2019          NOP       39.69      33
# 11  2019-2020          NOP       31.97      28
# 12  2018-2019          SAS       49.78      48
# 13  2017-2018          DAL       32.46      24
# 14  2019-2020          BOS       45.46      43
# 15  2019-2020          BRK       31.14      30
# 16  2018-2019          MIL       65.16      60
# 17  2018-2019          SAC       41.82      39
# 18  2018-2019          PHI       49.31      51
# 19  2019-2020          IND       37.44      39
# 20  2018-2019          ATL       26.81      29
# 21  2018-2019          DET       39.13      41
# 22  2018-2019          CLE       17.81      19

# %%
# Assign the data to X and y and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
predictions = model.predict(X_test)
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()

# %%
# Assign the data to X and y  and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# LASSO model

from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)

#Printing the model MSE and Score for evaluation
MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

# pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()

lasso_model = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lasso_model, how = 'left',left_index = True, right_index = True)

Lasso_Model_df = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
Lasso_Model_df

#Writing the results to a csv and viewing the output 
Lasso_Model_df.to_csv('../Data/Lasso_Model_Predictions.csv', index = False)

Lasso_Model_df
# Out:
# MSE: 13.081800676658327, R2: 0.9101776574690793
#        Season abbreviation  Prediction  Actual
# 0   2018-2019          ATL       26.32      29
# 1   2017-2018          LAC       41.53      42
# 2   2017-2018          MIL       39.47      44
# 3   2017-2018          GSW       56.42      58
# 4   2019-2020          CLE       18.12      19
# 5   2019-2020          MIL       57.95      53
# 6   2017-2018          DET       39.38      39
# 7   2018-2019          BOS       52.18      49
# 8   2019-2020          DEN       39.25      43
# 9   2019-2020          CHI       26.15      22
# 10  2019-2020          DAL       47.47      40
# 11  2017-2018          PHO       16.43      21
# 12  2019-2020          DET       25.45      20
# 13  2017-2018          UTA       48.91      48
# 14  2019-2020          LAL       47.86      49
# 15  2018-2019          UTA       52.39      50
# 16  2018-2019          ORL       41.26      42
# 17  2019-2020          OKC       38.58      40
# 18  2019-2020          ORL       29.98      30
# 19  2017-2018          BOS       47.66      55
# 20  2019-2020          LAC       46.58      44
# 21  2019-2020          POR       33.57      29
# 22  2018-2019          CLE       16.66      19

# %%
# Assign the data to X and y  and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# Ridge model

from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train, y_train)

predictions = ridge.predict(X_test)
predictions = predictions.flatten()

y_test = y_test.flatten()

#Printing the model MSE and Score for evaluation
MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

ridge_model = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, ridge_model, how = 'left',left_index = True, right_index = True)

Ridge_Model_df = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
Ridge_Model_df

#Writing the results to a csv and viewing the output 
Ridge_Model_df.to_csv('../Data/Ridge_Model_Predictions.csv', index = False)

Ridge_Model_df
# Out:
# MSE: 10.005828209960656, R2: 0.938288915694292
#        Season abbreviation  Prediction  Actual
# 0   2017-2018          LAL       37.87      35
# 1   2018-2019          DEN       49.99      54
# 2   2019-2020          OKC       38.99      40
# 3   2018-2019          NOP       40.37      33
# 4   2019-2020          NYK       19.65      21
# 5   2018-2019          SAS       47.90      48
# 6   2019-2020          MEM       31.72      32
# 7   2018-2019          TOR       57.68      58
# 8   2017-2018          WAS       41.43      43
# 9   2019-2020          CHI       25.64      22
# 10  2019-2020          GSW       13.08      15
# 11  2018-2019          BOS       52.49      49
# 12  2018-2019          MIL       65.46      60
# 13  2018-2019          ATL       26.39      29
# 14  2017-2018          IND       46.09      48
# 15  2017-2018          ORL       28.09      25
# 16  2017-2018          UTA       48.75      48
# 17  2017-2018          CHI       21.92      27
# 18  2019-2020          MIN       23.45      19
# 19  2018-2019          DET       38.03      41
# 20  2017-2018          DEN       43.47      46
# 21  2018-2019          LAC       45.75      48
# 22  2017-2018          OKC       47.22      48

# %%
# Assign the data to X and y and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# ElasticNet model

from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train, y_train)

predictions = elasticnet.predict(X_test)

#Printing the model MSE and Score for evaluation
MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

elastic_model = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, elastic_model, how = 'left',left_index = True, right_index = True)

ElasticNet_Model_df = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
ElasticNet_Model_df

#Writing the results to a csv and viewing the output 
ElasticNet_Model_df.to_csv('../Data/ElasticNet_Model_Predictions.csv', index = False)

ElasticNet_Model_df
# Out:
# MSE: 12.60418909418801, R2: 0.9177040726879109
#        Season abbreviation  Prediction  Actual
# 0   2018-2019          ATL       26.66      29
# 1   2019-2020          UTA       39.21      41
# 2   2019-2020          ORL       28.61      30
# 3   2018-2019          PHO       20.22      19
# 4   2017-2018          NOP       46.64      48
# 5   2019-2020          MIA       37.33      41
# 6   2018-2019          MEM       30.89      33
# 7   2018-2019          CLE       16.81      19
# 8   2017-2018          CHI       20.11      27
# 9   2019-2020          LAC       45.99      44
# 10  2017-2018          BRK       29.58      28
# 11  2018-2019          DEN       49.00      54
# 12  2017-2018          PHI       50.36      52
# 13  2019-2020          PHO       27.66      26
# 14  2019-2020          DAL       47.36      40
# 15  2017-2018          NYK       33.60      29
# 16  2018-2019          DAL       36.95      33
# 17  2017-2018          HOU       58.37      65
# 18  2019-2020          LAL       47.26      49
# 19  2017-2018          DEN       43.61      46
# 20  2019-2020          GSW       14.19      15
# 21  2017-2018          IND       44.82      48
# 22  2018-2019          WAS       35.82      32
