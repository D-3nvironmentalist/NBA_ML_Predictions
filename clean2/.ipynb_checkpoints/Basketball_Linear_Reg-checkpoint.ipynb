# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
from sportsreference.nba.teams import Teams
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# MIL                  0.742         1159  ...     2     480
# HOU                  0.787         1310  ...     3     541
# POR                  0.798         1145  ...     4     401
# ATL                  0.790         1237  ...     5     523
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                            2779                              0.369
# MIL                            2510                              0.356
# HOU                            2832                              0.348
# POR                            2228                              0.372
# ATL                            2416                              0.333
#
#      three_point_field_goals  total_rebounds  turnovers  \
# DAL                     1026            3150        857
# MIL                      893            3362        969
# HOU                      986            2875        939
# POR                      829            3001        858
# ATL                      805            2898       1086
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# DAL                           3248                            0.542
# MIL                           3418                            0.567
# HOU                           2971                            0.554
# POR                           3770                            0.513
# ATL                           3651                            0.525
#
#      two_point_field_goals
# DAL                   1761
# MIL                   1937
# HOU                   1646
# POR                   1934
# ATL                   1918
#
# [5 rows x 47 columns]

# %%
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# GSW                  0.801         1339  ...     2     625
# NOP                  0.761         1462  ...     3     610
# PHI                  0.771         1742  ...     4     606
# LAC                  0.792         1853  ...     5     561
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# MIL                            3134                              0.353
# GSW                            2824                              0.385
# NOP                            2449                              0.344
# PHI                            2474                              0.359
# LAC                            2118                              0.388
#
#      three_point_field_goals  total_rebounds  turnovers  \
# MIL                     1105            4078       1137
# GSW                     1087            3787       1169
# NOP                      842            3878       1215
# PHI                      889            3917       1223
# LAC                      821            3732       1193
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# MIL                           4337                            0.565
# GSW                           4537                            0.557
# NOP                           5114                            0.536
# PHI                           4759                            0.529
# LAC                           5060                            0.507
#
#      two_point_field_goals
# MIL                   2450
# GSW                   2525
# NOP                   2739
# PHI                   2518
# LAC                   2563
#
# [5 rows x 47 columns]

# %%
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# HOU                  0.781         1609  ...     2     699
# NOP                  0.772         1324  ...     3     657
# TOR                  0.794         1422  ...     4     626
# CLE                  0.779         1488  ...     5     582
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# GSW                            2370                              0.391
# HOU                            3470                              0.362
# NOP                            2312                              0.362
# TOR                            2705                              0.358
# CLE                            2636                              0.372
#
#      three_point_field_goals  total_rebounds  turnovers  \
# GSW                      926            3568       1267
# HOU                     1256            3564       1135
# NOP                      837            3636       1223
# TOR                      968            3607       1095
# CLE                      981            3455       1126
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# GSW                           4611                            0.560
# HOU                           3436                            0.558
# NOP                           4929                            0.540
# TOR                           4464                            0.541
# CLE                           4314                            0.540
#
#      two_point_field_goals
# GSW                   2583
# HOU                   1918
# NOP                   2663
# TOR                   2415
# CLE                   2330
#
# [5 rows x 47 columns]

# %%
wins_17_18 = pd.read_csv('team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
wins_18_19 = pd.read_csv('team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
wins_19_20 = pd.read_csv('team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20 = stats_19_20.assign(Season=['2019-2020'] * 30)
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1196  ...                             2779
# 1                  0.742         1159  ...                             2510
# 2                  0.787         1310  ...                             2832
# 3                  0.798         1145  ...                             2228
# 4                  0.790         1237  ...                             2416
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.369                    1026            3150
# 1                              0.356                     893            3362
# 2                              0.348                     986            2875
# 3                              0.372                     829            3001
# 4                              0.333                     805            2898
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0        857                           3248                            0.542
# 1        969                           3418                            0.567
# 2        939                           2971                            0.554
# 3        858                           3770                            0.513
# 4       1086                           3651                            0.525
#
#    two_point_field_goals   W     Season
# 0                   1761  40  2019-2020
# 1                   1937  53  2019-2020
# 2                   1646  40  2019-2020
# 3                   1934  29  2019-2020
# 4                   1918  20  2019-2020
#
# [5 rows x 49 columns]

# %%
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19 = stats_18_19.assign(Season=['2018-2019'] * 30)
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1471  ...                             3134
# 1                  0.801         1339  ...                             2824
# 2                  0.761         1462  ...                             2449
# 3                  0.771         1742  ...                             2474
# 4                  0.792         1853  ...                             2118
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.353                    1105            4078
# 1                              0.385                    1087            3787
# 2                              0.344                     842            3878
# 3                              0.359                     889            3917
# 4                              0.388                     821            3732
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1137                           4337                            0.565
# 1       1169                           4537                            0.557
# 2       1215                           5114                            0.536
# 3       1223                           4759                            0.529
# 4       1193                           5060                            0.507
#
#    two_point_field_goals   W     Season
# 0                   2450  60  2018-2019
# 1                   2525  57  2018-2019
# 2                   2739  33  2018-2019
# 3                   2518  51  2018-2019
# 4                   2563  48  2018-2019
#
# [5 rows x 49 columns]

# %%
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18 = stats_17_18.assign(Season=['2017-2018'] * 30)
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
# Assign the data to X and y

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (90, 16) (90, 1)

# %%
# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_test
# Out:
#                         assists  defensive_rebounds  field_goal_percentage  \
# abbreviation Season
# CLE          2017-2018     1916                2761                  0.476
# DAL          2018-2019     1918                2884                  0.447
# LAL          2018-2019     2096                2985                  0.470
# SAC          2018-2019     2083                2819                  0.464
# POR          2017-2018     1599                2893                  0.452
# DEN          2019-2020     1724                2179                  0.471
# HOU          2018-2019     1741                2613                  0.449
# DEN          2017-2018     2059                2748                  0.470
# OKC          2018-2019     1917                2911                  0.454
# DET          2017-2018     1868                2756                  0.450
# WAS          2017-2018     2065                2713                  0.467
# LAC          2019-2020     1526                2368                  0.464
# TOR          2018-2019     2085                2920                  0.474
# BOS          2017-2018     1842                2878                  0.450
# MIN          2018-2019     2018                2750                  0.456
# ATL          2018-2019     2118                2825                  0.451
# MIA          2017-2018     1862                2801                  0.455
# OKC          2017-2018     1750                2671                  0.453
# PHO          2019-2020     1766                2163                  0.464
# MIL          2018-2019     2136                3316                  0.476
# LAL          2017-2018     1949                2927                  0.461
# UTA          2017-2018     1839                2807                  0.462
# MEM          2017-2018     1767                2544                  0.444
#
#                         field_goals  opp_assists  opp_blocks  \
# abbreviation Season
# CLE          2017-2018         3311         2122         340
# DAL          2018-2019         3182         2011         368
# LAL          2018-2019         3491         2053         421
# SAC          2018-2019         3541         2024         420
# POR          2017-2018         3222         1655         418
# DEN          2019-2020         2719         1626         292
# HOU          2018-2019         3218         1929         369
# DEN          2017-2018         3338         2028         391
# OKC          2018-2019         3497         2039         415
# DET          2017-2018         3208         2064         398
# WAS          2017-2018         3275         1831         383
# LAC          2019-2020         2664         1508         314
# TOR          2018-2019         3460         2012         368
# BOS          2017-2018         3141         1744         364
# MIN          2018-2019         3413         2145         455
# ATL          2018-2019         3392         2202         448
# MIA          2017-2018         3184         1720         378
# OKC          2017-2018         3271         1911         377
# PHO          2019-2020         2650         1545         367
# MIL          2018-2019         3555         2031         395
# LAL          2017-2018         3338         1932         447
# UTA          2017-2018         3139         1636         380
# MEM          2017-2018         3013         1816         421
#
#                         opp_defensive_rebounds  opp_field_goal_percentage  \
# abbreviation Season
# CLE          2017-2018                    2766                      0.474
# DAL          2018-2019                    2840                      0.459
# LAL          2018-2019                    2918                      0.452
# SAC          2018-2019                    3015                      0.466
# POR          2017-2018                    2755                      0.447
# DEN          2019-2020                    2134                      0.459
# HOU          2018-2019                    2825                      0.466
# DEN          2017-2018                    2613                      0.476
# OKC          2018-2019                    2936                      0.460
# DET          2017-2018                    2833                      0.459
# WAS          2017-2018                    2682                      0.462
# LAC          2019-2020                    2216                      0.436
# TOR          2018-2019                    2804                      0.449
# BOS          2017-2018                    2804                      0.440
# MIN          2018-2019                    2822                      0.467
# ATL          2018-2019                    2904                      0.473
# MIA          2017-2018                    2791                      0.450
# OKC          2017-2018                    2676                      0.458
# PHO          2019-2020                    2236                      0.475
# MIL          2018-2019                    2902                      0.433
# LAL          2017-2018                    2835                      0.456
# UTA          2017-2018                    2702                      0.449
# MEM          2017-2018                    2703                      0.462
#
#                         opp_points  opp_three_point_field_goal_percentage  \
# abbreviation Season
# CLE          2017-2018        9014                                  0.368
# DAL          2018-2019        9032                                  0.344
# LAL          2018-2019        9306                                  0.349
# SAC          2018-2019        9455                                  0.348
# POR          2017-2018        8448                                  0.364
# DEN          2019-2020        6984                                  0.346
# HOU          2018-2019        8950                                  0.340
# DEN          2017-2018        8899                                  0.378
# OKC          2018-2019        9108                                  0.356
# DET          2017-2018        8521                                  0.359
# WAS          2017-2018        8694                                  0.349
# LAC          2019-2020        7019                                  0.341
# TOR          2018-2019        8885                                  0.345
# BOS          2017-2018        8235                                  0.339
# MIN          2018-2019        9346                                  0.378
# ATL          2018-2019        9788                                  0.359
# MIA          2017-2018        8441                                  0.360
# OKC          2017-2018        8564                                  0.367
# PHO          2019-2020        7405                                  0.368
# MIL          2018-2019        8959                                  0.361
# LAL          2017-2018        8989                                  0.346
# UTA          2017-2018        8187                                  0.365
# MEM          2017-2018        8654                                  0.368
#
#                         opp_total_rebounds  \
# abbreviation Season
# CLE          2017-2018                3578
# DAL          2018-2019                3676
# LAL          2018-2019                3842
# SAC          2018-2019                3932
# POR          2017-2018                3518
# DEN          2019-2020                2785
# HOU          2018-2019                3724
# DEN          2017-2018                3413
# OKC          2018-2019                3747
# DET          2017-2018                3589
# WAS          2017-2018                3487
# LAC          2019-2020                2911
# TOR          2018-2019                3671
# BOS          2017-2018                3595
# MIN          2018-2019                3743
# ATL          2018-2019                3775
# MIA          2017-2018                3535
# OKC          2017-2018                3457
# PHO          2019-2020                2836
# MIL          2018-2019                3715
# LAL          2017-2018                3675
# UTA          2017-2018                3412
# MEM          2017-2018                3485
#
#                         opp_two_point_field_goal_percentage  points  \
# abbreviation Season
# CLE          2017-2018                                0.533    9091
# DAL          2018-2019                                0.525    8927
# LAL          2018-2019                                0.511    9165
# SAC          2018-2019                                0.540    9363
# POR          2017-2018                                0.484    8661
# DEN          2019-2020                                0.531    7176
# HOU          2018-2019                                0.532    9341
# DEN          2017-2018                                0.525    9020
# OKC          2018-2019                                0.517    9387
# DET          2017-2018                                0.515    8509
# WAS          2017-2018                                0.522    8742
# LAC          2019-2020                                0.498    7436
# TOR          2018-2019                                0.505    9384
# BOS          2017-2018                                0.488    8529
# MIN          2018-2019                                0.520    9223
# ATL          2018-2019                                0.543    9294
# MIA          2017-2018                                0.491    8480
# OKC          2017-2018                                0.511    8844
# PHO          2019-2020                                0.537    7316
# MIL          2018-2019                                0.479    9686
# LAL          2017-2018                                0.512    8862
# UTA          2017-2018                                0.488    8540
# MEM          2017-2018                                0.516    8145
#
#                         three_point_field_goal_percentage  total_rebounds  \
# abbreviation Season
# CLE          2017-2018                              0.372            3455
# DAL          2018-2019                              0.340            3716
# LAL          2018-2019                              0.333            3820
# SAC          2018-2019                              0.378            3725
# POR          2017-2018                              0.366            3728
# DEN          2019-2020                              0.358            2878
# HOU          2018-2019                              0.356            3449
# DEN          2017-2018                              0.371            3650
# OKC          2018-2019                              0.348            3942
# DET          2017-2018                              0.373            3586
# WAS          2017-2018                              0.375            3536
# LAC          2019-2020                              0.366            3069
# TOR          2018-2019                              0.366            3706
# BOS          2017-2018                              0.377            3645
# MIN          2018-2019                              0.351            3673
# ATL          2018-2019                              0.352            3780
# MIA          2017-2018                              0.360            3564
# OKC          2017-2018                              0.354            3695
# PHO          2019-2020                              0.353            2800
# MIL          2018-2019                              0.353            4078
# LAL          2017-2018                              0.345            3803
# UTA          2017-2018                              0.366            3547
# MEM          2017-2018                              0.352            3323
#
#                         two_point_field_goal_percentage
# abbreviation Season
# CLE          2017-2018                            0.540
# DAL          2018-2019                            0.524
# LAL          2018-2019                            0.541
# SAC          2018-2019                            0.504
# POR          2017-2018                            0.493
# DEN          2019-2020                            0.529
# HOU          2018-2019                            0.551
# DEN          2017-2018                            0.525
# OKC          2018-2019                            0.510
# DET          2017-2018                            0.488
# WAS          2017-2018                            0.508
# LAC          2019-2020                            0.522
# TOR          2018-2019                            0.539
# BOS          2017-2018                            0.491
# MIN          2018-2019                            0.504
# ATL          2018-2019                            0.518
# MIA          2017-2018                            0.508
# OKC          2017-2018                            0.505
# PHO          2019-2020                            0.527
# MIL          2018-2019                            0.565
# LAL          2017-2018                            0.517
# UTA          2017-2018                            0.515
# MEM          2017-2018                            0.486

# %%
# Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
predictions = predictions.flatten()


MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")


lin_reg = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lin_reg, how = 'left',left_index = True, right_index = True)

df_out = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
df_out
# Out:
# MSE: 10.543400041257364, R2: 0.8987610066466067

# %%
# Assign the data to X and y  and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
predictions = model.predict(X_test)
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()

# %%
# Assign the data to X and y  and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# LASSO model

from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

# pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()

lasso_model = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lasso_model, how = 'left',left_index = True, right_index = True)

df_out = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
df_out

Lasso_Model_df.to_csv('Data/Lasso_Model_Predictions.csv', index = False)

Lasso_Model_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74cb88104722> in <module>
#       3 from sklearn.linear_model import Lasso
#       4
# ----> 5 lasso = Lasso(alpha=.01).fit(X_train, y_train)
#       6
#       7 predictions = lasso.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# Assign the data to X and y  and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# Ridge model

from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train, y_train)

predictions = ridge.predict(X_test)
predictions = predictions.flatten()

y_test = y_test.flatten()

MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

ridge_model = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, ridge_model, how = 'left',left_index = True, right_index = True)

df_out = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
df_out
# Out:
# MSE: 9.82011377145734, R2: 0.9309600740909451
#        Season abbreviation  Prediction  Actual
# 0   2017-2018          DET       39.70      39
# 1   2017-2018          IND       45.15      48
# 2   2019-2020          OKC       36.74      40
# 3   2018-2019          POR       54.14      53
# 4   2018-2019          CHI       20.82      22
# 5   2019-2020          ATL       17.02      20
# 6   2019-2020          PHI       35.87      39
# 7   2018-2019          PHI       48.71      51
# 8   2018-2019          SAS       47.20      48
# 9   2017-2018          LAL       37.79      35
# 10  2017-2018          MIL       37.82      44
# 11  2019-2020          DEN       38.10      43
# 12  2018-2019          MIL       64.26      60
# 13  2017-2018          MEM       22.46      22
# 14  2017-2018          CHI       21.97      27
# 15  2018-2019          PHO       16.68      19
# 16  2019-2020          BOS       44.36      43
# 17  2019-2020          HOU       38.76      40
# 18  2017-2018          MIN       46.11      47
# 19  2018-2019          ORL       41.14      42
# 20  2017-2018          HOU       58.16      65
# 21  2017-2018          UTA       48.20      48
# 22  2019-2020          IND       36.04      39

# %%
# Assign the data to X and y and reset model input

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)

# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# (90, 16) (90, 1)

# %%
# ElasticNet model

from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train, y_train)

predictions = elasticnet.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

elastic_model = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, elastic_model, how = 'left',left_index = True, right_index = True)

df_out = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
df_out
# Out:
# MSE: 9.161767913335789, R2: 0.9514672725746066
#        Season abbreviation  Prediction  Actual
# 0   2017-2018          IND       44.54      48
# 1   2018-2019          PHI       48.34      51
# 2   2018-2019          GSW       58.62      57
# 3   2018-2019          OKC       50.61      49
# 4   2017-2018          CHO       41.23      36
# 5   2018-2019          CHI       21.84      22
# 6   2017-2018          POR       47.35      49
# 7   2018-2019          MEM       31.25      33
# 8   2019-2020          UTA       39.67      41
# 9   2019-2020          POR       33.83      29
# 10  2018-2019          UTA       52.04      50
# 11  2019-2020          MIN       24.24      19
# 12  2019-2020          SAS       31.32      27
# 13  2019-2020          TOR       42.71      46
# 14  2019-2020          LAC       45.24      44
# 15  2018-2019          DEN       49.22      54
# 16  2018-2019          HOU       50.69      53
# 17  2018-2019          PHO       19.01      19
# 18  2019-2020          ATL       18.50      20
# 19  2018-2019          ORL       41.52      42
# 20  2019-2020          NYK       22.07      21
# 21  2017-2018          HOU       59.50      65
# 22  2019-2020          WAS       25.85      24
