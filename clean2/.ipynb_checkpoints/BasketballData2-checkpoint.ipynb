# %%
#Dependencies
import pandas as pd
from sportsreference.nba.teams import Teams

# %%
#Importing stats from the 2019-2020 NBA Season *A full regular season was not played due to Covid-19*
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# ...

# %%
#Importing stats from the 2018-2019 Season
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# ...

# %%
#Importing stats from the 2017-2018 season
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# ...

# %%
#Importing team wins from the 2017-2018 Season
wins_17_18 = pd.read_csv('../Data/team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
#Importing team wins form the 2018-2019 season
wins_18_19 = pd.read_csv('../Data/team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
#Importing team wins from the 2019-2020 season
wins_19_20 = pd.read_csv('../Data/team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
#Merging team stats with team wins for 2019-2020
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20 = stats_19_20.assign(Season=['2019-2020'] * 30)
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1196  ...                             2779
# ...

# %%
#Merging team stats for the 2018-2019 season
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19 = stats_18_19.assign(Season=['2018-2019'] * 30)
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1471  ...                             3134
# ...

# %%
#Mergin team stats for the 2017-2018 season
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18 = stats_17_18.assign(Season=['2017-2018'] * 30)
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# ...

# %%
#Concatinating the stats into one dataframe
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# ...

# %%
#Testing the correlation between each variable and wins
from scipy.stats import pearsonr

corr_test = stats_18_19.copy()

corr_test2 = corr_test.drop(columns = ["abbreviation","name"])

#Iterating the columns and printing mid-strength or above correlations
for col in corr_test2.columns: 
    r = pearsonr(corr_test2[col],corr_test2["W"])
    
    if r[0] > .4 or r[0] < -0.4:
        print(col)   
        print(r)
        print('-'*20)  
        
# #iterating the columns of the whole dataset 
# for col in df2.columns: 
    
#     print(col)
    
#     r = pearsonr(df2[col],df2["W"])
#     print(r)
# Out:
# assists
# (0.5018752386371438, 0.004716515832584487)
# --------------------
# blocks
# (0.44488840133252966, 0.013763238618732822)
# --------------------
# defensive_rebounds
# (0.5748840185417698, 0.0008907886376110736)
# --------------------
# field_goal_percentage
# (0.610832746305261, 0.00033684246718606583)
# --------------------
# field_goals
# (0.5259566102396459, 0.0028341275767959978)
# --------------------
# opp_assists
# (-0.5552837251522986, 0.0014465429378746053)
# --------------------
# opp_blocks
# (-0.5025427387233854, 0.004652659808976085)
# --------------------
# opp_defensive_rebounds
# (-0.5482242092392593, 0.0017102663138444992)
# --------------------
# opp_field_goal_percentage
# (-0.713078107223301, 9.768913299521885e-06)
# --------------------
# opp_field_goals
# (-0.4739653104578413, 0.008147672696084391)
# --------------------
# opp_points
# (-0.5418639789139984, 0.0019826587343636645)
# --------------------
# opp_three_point_field_goal_percentage
# ...

# %%
#Writing the concatonated dataframe to a csv
all_df.to_csv("total_stats.csv")

# %%
#testing stuff

teams = Teams("2017")
stats_16_17 = teams.dataframes

wins_16_17 = pd.read_csv('team_wins_16_17.csv')

stats_16_17 = stats_16_17.merge(wins_16_17, left_on='abbreviation', right_on='abbreviation')
stats_16_17 = stats_16_17.assign(Season=['2016-2017'] * 30)


new_df = [stats_16_17, stats_17_18, stats_18_19]

new_df = pd.concat(new_df).reset_index(drop=True)

new_df.to_csv("new_stats.csv")
new_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2491     555                2873                 7140
# 1          HOU     2070     352                2746                 7152
# 2          DEN     2077     323                2837                 7194
# 3          CLE     1858     327                2821                 6963
# 4          WAS     1956     336                2671                 7137
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.495         3532                 1850
# 1                  0.462         3305                 2177
# 2                  0.469         3377                 1986
# 3                  0.470         3275                 1913
# 4                  0.475         3388                 1812
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.788         1457  ...                             2562
# ...
