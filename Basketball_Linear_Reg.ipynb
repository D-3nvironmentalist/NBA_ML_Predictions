# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
from sportsreference.nba.teams import Teams
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# MIL                  0.742         1159  ...     2     480
# HOU                  0.787         1310  ...     3     541
# POR                  0.798         1145  ...     4     401
# ATL                  0.790         1237  ...     5     523
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                            2779                              0.369
# MIL                            2510                              0.356
# HOU                            2832                              0.348
# POR                            2228                              0.372
# ATL                            2416                              0.333
#
#      three_point_field_goals  total_rebounds  turnovers  \
# DAL                     1026            3150        857
# MIL                      893            3362        969
# HOU                      986            2875        939
# POR                      829            3001        858
# ATL                      805            2898       1086
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# DAL                           3248                            0.542
# MIL                           3418                            0.567
# HOU                           2971                            0.554
# POR                           3770                            0.513
# ATL                           3651                            0.525
#
#      two_point_field_goals
# DAL                   1761
# MIL                   1937
# HOU                   1646
# POR                   1934
# ATL                   1918
#
# [5 rows x 47 columns]

# %%
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# GSW                  0.801         1339  ...     2     625
# NOP                  0.761         1462  ...     3     610
# PHI                  0.771         1742  ...     4     606
# LAC                  0.792         1853  ...     5     561
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# MIL                            3134                              0.353
# GSW                            2824                              0.385
# NOP                            2449                              0.344
# PHI                            2474                              0.359
# LAC                            2118                              0.388
#
#      three_point_field_goals  total_rebounds  turnovers  \
# MIL                     1105            4078       1137
# GSW                     1087            3787       1169
# NOP                      842            3878       1215
# PHI                      889            3917       1223
# LAC                      821            3732       1193
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# MIL                           4337                            0.565
# GSW                           4537                            0.557
# NOP                           5114                            0.536
# PHI                           4759                            0.529
# LAC                           5060                            0.507
#
#      two_point_field_goals
# MIL                   2450
# GSW                   2525
# NOP                   2739
# PHI                   2518
# LAC                   2563
#
# [5 rows x 47 columns]

# %%
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# HOU                  0.781         1609  ...     2     699
# NOP                  0.772         1324  ...     3     657
# TOR                  0.794         1422  ...     4     626
# CLE                  0.779         1488  ...     5     582
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# GSW                            2370                              0.391
# HOU                            3470                              0.362
# NOP                            2312                              0.362
# TOR                            2705                              0.358
# CLE                            2636                              0.372
#
#      three_point_field_goals  total_rebounds  turnovers  \
# GSW                      926            3568       1267
# HOU                     1256            3564       1135
# NOP                      837            3636       1223
# TOR                      968            3607       1095
# CLE                      981            3455       1126
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# GSW                           4611                            0.560
# HOU                           3436                            0.558
# NOP                           4929                            0.540
# TOR                           4464                            0.541
# CLE                           4314                            0.540
#
#      two_point_field_goals
# GSW                   2583
# HOU                   1918
# NOP                   2663
# TOR                   2415
# CLE                   2330
#
# [5 rows x 47 columns]

# %%
wins_17_18 = pd.read_csv('team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
wins_18_19 = pd.read_csv('team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
wins_19_20 = pd.read_csv('team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20 = stats_19_20.assign(Season=['2019-2020'] * 30)
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1196  ...                             2779
# 1                  0.742         1159  ...                             2510
# 2                  0.787         1310  ...                             2832
# 3                  0.798         1145  ...                             2228
# 4                  0.790         1237  ...                             2416
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.369                    1026            3150
# 1                              0.356                     893            3362
# 2                              0.348                     986            2875
# 3                              0.372                     829            3001
# 4                              0.333                     805            2898
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0        857                           3248                            0.542
# 1        969                           3418                            0.567
# 2        939                           2971                            0.554
# 3        858                           3770                            0.513
# 4       1086                           3651                            0.525
#
#    two_point_field_goals   W     Season
# 0                   1761  40  2019-2020
# 1                   1937  53  2019-2020
# 2                   1646  40  2019-2020
# 3                   1934  29  2019-2020
# 4                   1918  20  2019-2020
#
# [5 rows x 49 columns]

# %%
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19 = stats_18_19.assign(Season=['2018-2019'] * 30)
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1471  ...                             3134
# 1                  0.801         1339  ...                             2824
# 2                  0.761         1462  ...                             2449
# 3                  0.771         1742  ...                             2474
# 4                  0.792         1853  ...                             2118
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.353                    1105            4078
# 1                              0.385                    1087            3787
# 2                              0.344                     842            3878
# 3                              0.359                     889            3917
# 4                              0.388                     821            3732
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1137                           4337                            0.565
# 1       1169                           4537                            0.557
# 2       1215                           5114                            0.536
# 3       1223                           4759                            0.529
# 4       1193                           5060                            0.507
#
#    two_point_field_goals   W     Season
# 0                   2450  60  2018-2019
# 1                   2525  57  2018-2019
# 2                   2739  33  2018-2019
# 3                   2518  51  2018-2019
# 4                   2563  48  2018-2019
#
# [5 rows x 49 columns]

# %%
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18 = stats_17_18.assign(Season=['2017-2018'] * 30)
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
# Assign the data to X and y

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (90, 16) (90, 1)

# %%
# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_test
# Out:
#                         assists  defensive_rebounds  field_goal_percentage  \
# abbreviation Season
# PHO          2018-2019     1957                2563                  0.459
# IND          2019-2020     1686                2211                  0.477
# CLE          2019-2020     1500                2172                  0.458
#              2018-2019     1698                2619                  0.444
# LAL          2017-2018     1949                2927                  0.461
# IND          2017-2018     1819                2684                  0.472
# ORL          2019-2020     1559                2220                  0.442
# ATL          2017-2018     1946                2693                  0.446
# DET          2018-2019     1845                2752                  0.440
# BOS          2019-2020     1459                2259                  0.459
# CHI          2017-2018     1923                2873                  0.435
# PHO          2019-2020     1766                2163                  0.464
# CHO          2018-2019     1905                2778                  0.448
# MIN          2017-2018     1861                2593                  0.476
# LAC          2018-2019     1970                2936                  0.471
# UTA          2018-2019     2133                2981                  0.468
# BOS          2018-2019     2155                2849                  0.465
# GSW          2017-2018     2402                2877                  0.503
#              2019-2020     1663                2138                  0.438
# DET          2017-2018     1868                2756                  0.450
# CLE          2017-2018     1916                2761                  0.476
# PHI          2019-2020     1682                2282                  0.465
# NYK          2017-2018     1912                2752                  0.464
#
#                         field_goals  opp_assists  opp_blocks  \
# abbreviation Season
# PHO          2018-2019         3289         2126         411
# IND          2019-2020         2740         1505         291
# CLE          2019-2020         2619         1699         412
#              2018-2019         3189         2107         459
# LAL          2017-2018         3338         1932         447
# IND          2017-2018         3345         1905         428
# ORL          2019-2020         2550         1591         312
# ATL          2017-2018         3130         2137         453
# DET          2018-2019         3185         1940         419
# BOS          2019-2020         2634         1420         356
# CHI          2017-2018         3170         2123         423
# PHO          2019-2020         2650         1545         367
# CHO          2018-2019         3297         2133         492
# MIN          2017-2018         3365         1962         382
# LAC          2018-2019         3384         1976         498
# UTA          2018-2019         3314         1770         376
# BOS          2018-2019         3451         1940         317
# GSW          2017-2018         3509         1934         301
#              2019-2020         2510         1698         321
# DET          2017-2018         3208         2064         398
# CLE          2017-2018         3311         2122         340
# PHI          2019-2020         2651         1475         251
# NYK          2017-2018         3334         1965         389
#
#                         opp_defensive_rebounds  opp_field_goal_percentage  \
# abbreviation Season
# PHO          2018-2019                    2897                      0.482
# IND          2019-2020                    2249                      0.448
# CLE          2019-2020                    2154                      0.491
#              2018-2019                    2835                      0.495
# LAL          2017-2018                    2835                      0.456
# IND          2017-2018                    2686                      0.465
# ORL          2019-2020                    2339                      0.463
# ATL          2017-2018                    2785                      0.469
# DET          2018-2019                    2834                      0.469
# BOS          2019-2020                    2179                      0.442
# CHI          2017-2018                    3053                      0.472
# PHO          2019-2020                    2236                      0.475
# CHO          2018-2019                    2931                      0.470
# MIN          2017-2018                    2626                      0.475
# LAC          2018-2019                    2826                      0.457
# UTA          2018-2019                    2762                      0.452
# BOS          2018-2019                    2912                      0.448
# GSW          2017-2018                    2592                      0.447
#              2019-2020                    2359                      0.476
# DET          2017-2018                    2833                      0.459
# CLE          2017-2018                    2766                      0.474
# PHI          2019-2020                    2166                      0.462
# NYK          2017-2018                    2702                      0.457
#
#                         opp_points  opp_three_point_field_goal_percentage  \
# abbreviation Season
# PHO          2018-2019        9581                                  0.372
# IND          2019-2020        6981                                  0.345
# CLE          2019-2020        7461                                  0.375
#              2018-2019        9355                                  0.380
# LAL          2017-2018        8989                                  0.346
# IND          2017-2018        8543                                  0.349
# ORL          2019-2020        6977                                  0.370
# ATL          2017-2018        8922                                  0.377
# DET          2018-2019        8798                                  0.345
# BOS          2019-2020        6837                                  0.342
# CHI          2017-2018        9017                                  0.370
# PHO          2019-2020        7405                                  0.368
# CHO          2018-2019        9171                                  0.361
# MIN          2017-2018        8797                                  0.366
# LAC          2018-2019        9372                                  0.343
# UTA          2018-2019        8730                                  0.355
# BOS          2018-2019        8852                                  0.344
# GSW          2017-2018        8814                                  0.357
#              2019-2020        7478                                  0.389
# DET          2017-2018        8521                                  0.359
# CLE          2017-2018        9014                                  0.368
# PHI          2019-2020        6979                                  0.354
# NYK          2017-2018        8858                                  0.368
#
#                         opp_total_rebounds  \
# abbreviation Season
# PHO          2018-2019                3868
# IND          2019-2020                2906
# CLE          2019-2020                2787
#              2018-2019                3617
# LAL          2017-2018                3675
# IND          2017-2018                3524
# ORL          2019-2020                2930
# ATL          2017-2018                3626
# DET          2018-2019                3581
# BOS          2019-2020                2834
# CHI          2017-2018                3744
# PHO          2019-2020                2836
# CHO          2018-2019                3756
# MIN          2017-2018                3429
# LAC          2018-2019                3751
# UTA          2018-2019                3495
# BOS          2018-2019                3764
# GSW          2017-2018                3485
#              2019-2020                3020
# DET          2017-2018                3589
# CLE          2017-2018                3578
# PHI          2019-2020                2722
# NYK          2017-2018                3540
#
#                         opp_two_point_field_goal_percentage  points  \
# abbreviation Season
# PHO          2018-2019                                0.538    8815
# IND          2019-2020                                0.510    7107
# CLE          2019-2020                                0.558    6948
#              2018-2019                                0.561    8567
# LAL          2017-2018                                0.512    8862
# IND          2017-2018                                0.530    8656
# ORL          2019-2020                                0.522    6914
# ATL          2017-2018                                0.520    8475
# DET          2018-2019                                0.530    8778
# BOS          2019-2020                                0.507    7232
# CHI          2017-2018                                0.534    8440
# PHO          2019-2020                                0.537    7316
# CHO          2018-2019                                0.536    9081
# MIN          2017-2018                                0.534    8980
# LAC          2018-2019                                0.513    9442
# UTA          2018-2019                                0.496    9161
# BOS          2018-2019                                0.513    9216
# GSW          2017-2018                                0.490    9304
#              2019-2020                                0.533    6912
# DET          2017-2018                                0.515    8509
# CLE          2017-2018                                0.533    9091
# PHI          2019-2020                                0.518    7123
# NYK          2017-2018                                0.505    8566
#
#                         three_point_field_goal_percentage  total_rebounds  \
# abbreviation Season
# PHO          2018-2019                              0.329            3311
# IND          2019-2020                              0.363            2784
# CLE          2019-2020                              0.351            2876
#              2018-2019                              0.355            3498
# LAL          2017-2018                              0.345            3803
# IND          2017-2018                              0.369            3472
# ORL          2019-2020                              0.341            2894
# ATL          2017-2018                              0.360            3436
# DET          2018-2019                              0.348            3688
# BOS          2019-2020                              0.363            2942
# CHI          2017-2018                              0.355            3663
# PHO          2019-2020                              0.353            2800
# CHO          2018-2019                              0.351            3592
# MIN          2017-2018                              0.357            3441
# LAC          2018-2019                              0.388            3732
# UTA          2018-2019                              0.356            3801
# BOS          2018-2019                              0.365            3653
# GSW          2017-2018                              0.391            3568
#              2019-2020                              0.334            2785
# DET          2017-2018                              0.373            3586
# CLE          2017-2018                              0.372            3455
# PHI          2019-2020                              0.362            2955
# NYK          2017-2018                              0.352            3611
#
#                         two_point_field_goal_percentage
# abbreviation Season
# PHO          2018-2019                            0.525
# IND          2019-2020                            0.529
# CLE          2019-2020                            0.519
#              2018-2019                            0.488
# LAL          2017-2018                            0.517
# IND          2017-2018                            0.513
# ORL          2019-2020                            0.498
# ATL          2017-2018                            0.495
# DET          2018-2019                            0.500
# BOS          2019-2020                            0.519
# CHI          2017-2018                            0.478
# PHO          2019-2020                            0.527
# CHO          2018-2019                            0.507
# MIN          2017-2018                            0.519
# LAC          2018-2019                            0.507
# UTA          2018-2019                            0.541
# BOS          2018-2019                            0.527
# GSW          2017-2018                            0.560
#              2019-2020                            0.495
# DET          2017-2018                            0.488
# CLE          2017-2018                            0.540
# PHI          2019-2020                            0.523
# NYK          2017-2018                            0.504

# %%
# Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
predictions = predictions.flatten()


MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")


lin_reg = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lin_reg, how = 'left',left_index = True, right_index = True)

df_out = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
df_out
# Out:
# MSE: 10.289410371538903, R2: 0.9278907041685115
#        Season abbreviation  Prediction  Actual
# 0   2018-2019          PHO       17.68      19
# 1   2019-2020          IND       39.12      39
# 2   2019-2020          CLE       15.08      19
# 3   2018-2019          CLE       16.15      19
# 4   2017-2018          LAL       38.13      35
# 5   2017-2018          IND       45.80      48
# 6   2019-2020          ORL       27.57      30
# 7   2017-2018          ATL       24.92      24
# 8   2018-2019          DET       40.61      41
# 9   2019-2020          BOS       46.41      43
# 10  2017-2018          CHI       20.69      27
# 11  2019-2020          PHO       28.13      26
# 12  2018-2019          CHO       37.56      39
# 13  2017-2018          MIN       47.92      47
# 14  2018-2019          LAC       47.82      48
# 15  2018-2019          UTA       51.40      50
# 16  2018-2019          BOS       52.33      49
# 17  2017-2018          GSW       56.29      58
# 18  2019-2020          GSW       10.88      15
# 19  2017-2018          DET       39.69      39
# 20  2017-2018          CLE       41.70      50
# 21  2019-2020          PHI       37.89      39
# 22  2017-2018          NYK       34.23      29

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
predictions = model.predict(X_test)
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()

# %%
# LASSO model

from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()
# Out:
# MSE: 15.970225937503129, R2: 0.8802549960179845
#    Prediction  Actual
# 0       40.71      43
# 1       65.81      60
# 2       37.23      39
# 3       37.04      41
# 4       34.75      32

# %%
# Ridge model

from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train, y_train)

predictions = ridge.predict(X_test)
predictions = predictions.flatten()

y_test = y_test.flatten()

MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test}).reset_index(drop=True).head()
# Out:
# MSE: 14.677243691011165, R2: 0.8899497971348097
#    Prediction  Actual
# 0       41.02      43
# 1       65.20      60
# 2       37.39      39
# 3       37.24      41
# 4       34.27      32

# %%
# ElasticNet model

from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train, y_train)

predictions = elasticnet.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()
# Out:
# MSE: 15.971982125368875, R2: 0.8802418280938864
#    Prediction  Actual
# 0       40.71      43
# 1       65.81      60
# 2       37.24      39
# 3       37.03      41
# 4       34.75      32
