# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
from sportsreference.nba.teams import Teams
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# MIL                  0.742         1159  ...     2     480
# HOU                  0.787         1310  ...     3     541
# POR                  0.798         1145  ...     4     401
# ATL                  0.790         1237  ...     5     523
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                            2779                              0.369
# MIL                            2510                              0.356
# HOU                            2832                              0.348
# POR                            2228                              0.372
# ATL                            2416                              0.333
#
#      three_point_field_goals  total_rebounds  turnovers  \
# DAL                     1026            3150        857
# MIL                      893            3362        969
# HOU                      986            2875        939
# POR                      829            3001        858
# ATL                      805            2898       1086
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# DAL                           3248                            0.542
# MIL                           3418                            0.567
# HOU                           2971                            0.554
# POR                           3770                            0.513
# ATL                           3651                            0.525
#
#      two_point_field_goals
# DAL                   1761
# MIL                   1937
# HOU                   1646
# POR                   1934
# ATL                   1918
#
# [5 rows x 47 columns]

# %%
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# GSW                  0.801         1339  ...     2     625
# NOP                  0.761         1462  ...     3     610
# PHI                  0.771         1742  ...     4     606
# LAC                  0.792         1853  ...     5     561
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# MIL                            3134                              0.353
# GSW                            2824                              0.385
# NOP                            2449                              0.344
# PHI                            2474                              0.359
# LAC                            2118                              0.388
#
#      three_point_field_goals  total_rebounds  turnovers  \
# MIL                     1105            4078       1137
# GSW                     1087            3787       1169
# NOP                      842            3878       1215
# PHI                      889            3917       1223
# LAC                      821            3732       1193
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# MIL                           4337                            0.565
# GSW                           4537                            0.557
# NOP                           5114                            0.536
# PHI                           4759                            0.529
# LAC                           5060                            0.507
#
#      two_point_field_goals
# MIL                   2450
# GSW                   2525
# NOP                   2739
# PHI                   2518
# LAC                   2563
#
# [5 rows x 47 columns]

# %%
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# HOU                  0.781         1609  ...     2     699
# NOP                  0.772         1324  ...     3     657
# TOR                  0.794         1422  ...     4     626
# CLE                  0.779         1488  ...     5     582
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# GSW                            2370                              0.391
# HOU                            3470                              0.362
# NOP                            2312                              0.362
# TOR                            2705                              0.358
# CLE                            2636                              0.372
#
#      three_point_field_goals  total_rebounds  turnovers  \
# GSW                      926            3568       1267
# HOU                     1256            3564       1135
# NOP                      837            3636       1223
# TOR                      968            3607       1095
# CLE                      981            3455       1126
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# GSW                           4611                            0.560
# HOU                           3436                            0.558
# NOP                           4929                            0.540
# TOR                           4464                            0.541
# CLE                           4314                            0.540
#
#      two_point_field_goals
# GSW                   2583
# HOU                   1918
# NOP                   2663
# TOR                   2415
# CLE                   2330
#
# [5 rows x 47 columns]

# %%
wins_17_18 = pd.read_csv('team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
wins_18_19 = pd.read_csv('team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
wins_19_20 = pd.read_csv('team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  steals  \
# 0                  0.773         1196  ...     419
# 1                  0.742         1159  ...     480
# 2                  0.787         1310  ...     541
# 3                  0.798         1145  ...     401
# 4                  0.790         1237  ...     523
#
#    three_point_field_goal_attempts three_point_field_goal_percentage  \
# 0                             2779                             0.369
# 1                             2510                             0.356
# 2                             2832                             0.348
# 3                             2228                             0.372
# 4                             2416                             0.333
#
#    three_point_field_goals  total_rebounds  turnovers  \
# 0                     1026            3150        857
# 1                      893            3362        969
# 2                      986            2875        939
# 3                      829            3001        858
# 4                      805            2898       1086
#
#    two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0                           3248                            0.542
# 1                           3418                            0.567
# 2                           2971                            0.554
# 3                           3770                            0.513
# 4                           3651                            0.525
#
#    two_point_field_goals   W
# 0                   1761  40
# 1                   1937  53
# 2                   1646  40
# 3                   1934  29
# 4                   1918  20
#
# [5 rows x 48 columns]

# %%
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  steals  \
# 0                  0.773         1471  ...     615
# 1                  0.801         1339  ...     625
# 2                  0.761         1462  ...     610
# 3                  0.771         1742  ...     606
# 4                  0.792         1853  ...     561
#
#    three_point_field_goal_attempts three_point_field_goal_percentage  \
# 0                             3134                             0.353
# 1                             2824                             0.385
# 2                             2449                             0.344
# 3                             2474                             0.359
# 4                             2118                             0.388
#
#    three_point_field_goals  total_rebounds  turnovers  \
# 0                     1105            4078       1137
# 1                     1087            3787       1169
# 2                      842            3878       1215
# 3                      889            3917       1223
# 4                      821            3732       1193
#
#    two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0                           4337                            0.565
# 1                           4537                            0.557
# 2                           5114                            0.536
# 3                           4759                            0.529
# 4                           5060                            0.507
#
#    two_point_field_goals   W
# 0                   2450  60
# 1                   2525  57
# 2                   2739  33
# 3                   2518  51
# 4                   2563  48
#
# [5 rows x 48 columns]

# %%
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  steals  \
# 0                  0.815         1360  ...     656
# 1                  0.781         1609  ...     699
# 2                  0.772         1324  ...     657
# 3                  0.794         1422  ...     626
# 4                  0.779         1488  ...     582
#
#    three_point_field_goal_attempts three_point_field_goal_percentage  \
# 0                             2370                             0.391
# 1                             3470                             0.362
# 2                             2312                             0.362
# 3                             2705                             0.358
# 4                             2636                             0.372
#
#    three_point_field_goals  total_rebounds  turnovers  \
# 0                      926            3568       1267
# 1                     1256            3564       1135
# 2                      837            3636       1223
# 3                      968            3607       1095
# 4                      981            3455       1126
#
#    two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0                           4611                            0.560
# 1                           3436                            0.558
# 2                           4929                            0.540
# 3                           4464                            0.541
# 4                           4314                            0.540
#
#    two_point_field_goals   W
# 0                   2583  58
# 1                   1918  65
# 2                   2663  48
# 3                   2415  59
# 4                   2330  50
#
# [5 rows x 48 columns]

# %%
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  steals  \
# 0                  0.815         1360  ...     656
# 1                  0.781         1609  ...     699
# 2                  0.772         1324  ...     657
# 3                  0.794         1422  ...     626
# 4                  0.779         1488  ...     582
#
#    three_point_field_goal_attempts three_point_field_goal_percentage  \
# 0                             2370                             0.391
# 1                             3470                             0.362
# 2                             2312                             0.362
# 3                             2705                             0.358
# 4                             2636                             0.372
#
#    three_point_field_goals  total_rebounds  turnovers  \
# 0                      926            3568       1267
# 1                     1256            3564       1135
# 2                      837            3636       1223
# 3                      968            3607       1095
# 4                      981            3455       1126
#
#    two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0                           4611                            0.560
# 1                           3436                            0.558
# 2                           4929                            0.540
# 3                           4464                            0.541
# 4                           4314                            0.540
#
#    two_point_field_goals   W
# 0                   2583  58
# 1                   1918  65
# 2                   2663  48
# 3                   2415  59
# 4                   2330  50
#
# [5 rows x 48 columns]

# %%
# Assign the data to X and y

X = all_df[["assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']]
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (90, 16) (90, 1)

# %%
# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
#from sklearn.linear_model import LinearRegression
#model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

#model.fit(X_train, y_train)
#training_score = model.score(X_train, y_train)
#testing_score = model.score(X_test, y_test)

#print(f"Training Score: {training_score}")
#print(f"Testing Score: {testing_score}")

# %%
# Plot the Residuals for the Training and Testing data

#plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2018-2019 Training Data")
#plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="2018-2019 Testing Data")
#plt.legend()
#plt.hlines(y=0, xmin=y.min(), xmax=y.max())
#plt.title("Residual Plot")

# %%
# Create a StandardScater model and fit it to the training data

#from sklearn.preprocessing import StandardScaler

#X_scaler = StandardScaler().fit(X_train)
#y_scaler = StandardScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)
#y_train_scaled = y_scaler.transform(y_train)
#y_test_scaled = y_scaler.transform(y_test)

# %%
# Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
predictions = model.predict(X_test)
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 18.879994555251653, R2: 0.8635286794965003

# %%
# LASSO model

from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()
# Out:
# MSE: 20.946368250478557, R2: 0.8485921949537719
#    Prediction  Actual
# 0       66.57      60
# 1       33.57      29
# 2       16.27      23
# 3       36.72      40
# 4       31.87      28

# %%
# Ridge model

from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train, y_train)

predictions = ridge.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": [np.round(predictions , 2)], "Actual": [y_test.ravel()]}, index=[0]).head()
# Out:
# MSE: 19.80504518090239, R2: 0.856842084325845
#                                           Prediction  \
# 0  [[65.77], [33.33], [16.93], [37.09], [32.23], ...
#
#                                               Actual
# 0  [60, 29, 23, 40, 28, 24, 19, 58, 55, 44, 41, 4...

# %%
# ElasticNet model

from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train, y_train)

predictions = elasticnet.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()
# Out:
# MSE: 20.941774650411222, R2: 0.8486253991300348
#    Prediction  Actual
# 0       66.57      60
# 1       33.56      29
# 2       16.28      23
# 3       36.72      40
# 4       31.87      28
