# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas as pd
from sportsreference.nba.teams import Teams
teams = Teams("2020")

stats_19_20 = teams.dataframes

stats_19_20.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# DAL          DAL     1640     334                2438                 6027
# MIL          MIL     1685     390                2745                 5928
# HOU          HOU     1375     329                2212                 5803
# POR          POR     1333     411                2335                 5998
# ATL          ATL     1605     341                2237                 6067
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# DAL                  0.462         2787                 1548
# MIL                  0.477         2830                 1562
# HOU                  0.454         2632                 1664
# POR                  0.461         2763                 1434
# ATL                  0.449         2723                 1566
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# DAL                  0.773         1196  ...     1     419
# MIL                  0.742         1159  ...     2     480
# HOU                  0.787         1310  ...     3     541
# POR                  0.798         1145  ...     4     401
# ATL                  0.790         1237  ...     5     523
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# DAL                            2779                              0.369
# MIL                            2510                              0.356
# HOU                            2832                              0.348
# POR                            2228                              0.372
# ATL                            2416                              0.333
#
#      three_point_field_goals  total_rebounds  turnovers  \
# DAL                     1026            3150        857
# MIL                      893            3362        969
# HOU                      986            2875        939
# POR                      829            3001        858
# ATL                      805            2898       1086
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# DAL                           3248                            0.542
# MIL                           3418                            0.567
# HOU                           2971                            0.554
# POR                           3770                            0.513
# ATL                           3651                            0.525
#
#      two_point_field_goals
# DAL                   1761
# MIL                   1937
# HOU                   1646
# POR                   1934
# ATL                   1918
#
# [5 rows x 47 columns]

# %%
teams = Teams("2019")

stats_18_19 = teams.dataframes

stats_18_19.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# MIL          MIL     2136     486                3316                 7471
# GSW          GSW     2413     525                2990                 7361
# NOP          NOP     2216     441                2969                 7563
# PHI          PHI     2207     432                3025                 7233
# LAC          LAC     1970     385                2936                 7178
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# MIL                  0.476         3555                 1904
# GSW                  0.491         3612                 1672
# NOP                  0.473         3581                 1921
# PHI                  0.471         3407                 2258
# LAC                  0.471         3384                 2340
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# MIL                  0.773         1471  ...     1     615
# GSW                  0.801         1339  ...     2     625
# NOP                  0.761         1462  ...     3     610
# PHI                  0.771         1742  ...     4     606
# LAC                  0.792         1853  ...     5     561
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# MIL                            3134                              0.353
# GSW                            2824                              0.385
# NOP                            2449                              0.344
# PHI                            2474                              0.359
# LAC                            2118                              0.388
#
#      three_point_field_goals  total_rebounds  turnovers  \
# MIL                     1105            4078       1137
# GSW                     1087            3787       1169
# NOP                      842            3878       1215
# PHI                      889            3917       1223
# LAC                      821            3732       1193
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# MIL                           4337                            0.565
# GSW                           4537                            0.557
# NOP                           5114                            0.536
# PHI                           4759                            0.529
# LAC                           5060                            0.507
#
#      two_point_field_goals
# MIL                   2450
# GSW                   2525
# NOP                   2739
# PHI                   2518
# LAC                   2563
#
# [5 rows x 47 columns]

# %%
stats_17_18 = Teams("2018").dataframes

stats_17_18.head()
# Out:
#     abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# GSW          GSW     2402     612                2877                 6981
# HOU          HOU     1767     392                2825                 6906
# NOP          NOP     2195     485                2924                 7241
# TOR          TOR     1995     500                2807                 7169
# CLE          CLE     1916     312                2761                 6950
#
#      field_goal_percentage  field_goals  free_throw_attempts  \
# GSW                  0.503         3509                 1668
# HOU                  0.460         3174                 2061
# NOP                  0.483         3500                 1716
# TOR                  0.472         3383                 1790
# CLE                  0.476         3311                 1909
#
#      free_throw_percentage  free_throws  ...  rank  steals  \
# GSW                  0.815         1360  ...     1     656
# HOU                  0.781         1609  ...     2     699
# NOP                  0.772         1324  ...     3     657
# TOR                  0.794         1422  ...     4     626
# CLE                  0.779         1488  ...     5     582
#
#     three_point_field_goal_attempts  three_point_field_goal_percentage  \
# GSW                            2370                              0.391
# HOU                            3470                              0.362
# NOP                            2312                              0.362
# TOR                            2705                              0.358
# CLE                            2636                              0.372
#
#      three_point_field_goals  total_rebounds  turnovers  \
# GSW                      926            3568       1267
# HOU                     1256            3564       1135
# NOP                      837            3636       1223
# TOR                      968            3607       1095
# CLE                      981            3455       1126
#
#      two_point_field_goal_attempts  two_point_field_goal_percentage  \
# GSW                           4611                            0.560
# HOU                           3436                            0.558
# NOP                           4929                            0.540
# TOR                           4464                            0.541
# CLE                           4314                            0.540
#
#      two_point_field_goals
# GSW                   2583
# HOU                   1918
# NOP                   2663
# TOR                   2415
# CLE                   2330
#
# [5 rows x 47 columns]

# %%
wins_17_18 = pd.read_csv('Data/team_wins_17_18.csv')  
wins_17_18.head()
# Out:
#   abbreviation   W
# 0          TOR  59
# 1          BOS  55
# 2          PHI  52
# 3          CLE  50
# 4          IND  48

# %%
wins_18_19 = pd.read_csv('Data/team_wins_18_19.csv')  
wins_18_19.head()
# Out:
#   abbreviation   W
# 0          MIL  60
# 1          TOR  58
# 2          PHI  51
# 3          BOS  49
# 4          IND  48

# %%
wins_19_20 = pd.read_csv('Data/team_wins_19_20.csv')  
wins_19_20.head()
# Out:
#   abbreviation   W
# 0          MIL  53
# 1          TOR  46
# 2          BOS  43
# 3          MIA  41
# 4          IND  39

# %%
stats_19_20 = stats_19_20.merge(wins_19_20, left_on='abbreviation', right_on='abbreviation')
stats_19_20 = stats_19_20.assign(Season=['2019-2020'] * 30)
stats_19_20.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          DAL     1640     334                2438                 6027
# 1          MIL     1685     390                2745                 5928
# 2          HOU     1375     329                2212                 5803
# 3          POR     1333     411                2335                 5998
# 4          ATL     1605     341                2237                 6067
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.462         2787                 1548
# 1                  0.477         2830                 1562
# 2                  0.454         2632                 1664
# 3                  0.461         2763                 1434
# 4                  0.449         2723                 1566
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1196  ...                             2779
# 1                  0.742         1159  ...                             2510
# 2                  0.787         1310  ...                             2832
# 3                  0.798         1145  ...                             2228
# 4                  0.790         1237  ...                             2416
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.369                    1026            3150
# 1                              0.356                     893            3362
# 2                              0.348                     986            2875
# 3                              0.372                     829            3001
# 4                              0.333                     805            2898
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0        857                           3248                            0.542
# 1        969                           3418                            0.567
# 2        939                           2971                            0.554
# 3        858                           3770                            0.513
# 4       1086                           3651                            0.525
#
#    two_point_field_goals   W     Season
# 0                   1761  40  2019-2020
# 1                   1937  53  2019-2020
# 2                   1646  40  2019-2020
# 3                   1934  29  2019-2020
# 4                   1918  20  2019-2020
#
# [5 rows x 49 columns]

# %%
stats_18_19 = stats_18_19.merge(wins_18_19, left_on='abbreviation', right_on='abbreviation')
stats_18_19 = stats_18_19.assign(Season=['2018-2019'] * 30)
stats_18_19.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          MIL     2136     486                3316                 7471
# 1          GSW     2413     525                2990                 7361
# 2          NOP     2216     441                2969                 7563
# 3          PHI     2207     432                3025                 7233
# 4          LAC     1970     385                2936                 7178
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.476         3555                 1904
# 1                  0.491         3612                 1672
# 2                  0.473         3581                 1921
# 3                  0.471         3407                 2258
# 4                  0.471         3384                 2340
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.773         1471  ...                             3134
# 1                  0.801         1339  ...                             2824
# 2                  0.761         1462  ...                             2449
# 3                  0.771         1742  ...                             2474
# 4                  0.792         1853  ...                             2118
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.353                    1105            4078
# 1                              0.385                    1087            3787
# 2                              0.344                     842            3878
# 3                              0.359                     889            3917
# 4                              0.388                     821            3732
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1137                           4337                            0.565
# 1       1169                           4537                            0.557
# 2       1215                           5114                            0.536
# 3       1223                           4759                            0.529
# 4       1193                           5060                            0.507
#
#    two_point_field_goals   W     Season
# 0                   2450  60  2018-2019
# 1                   2525  57  2018-2019
# 2                   2739  33  2018-2019
# 3                   2518  51  2018-2019
# 4                   2563  48  2018-2019
#
# [5 rows x 49 columns]

# %%
stats_17_18 = stats_17_18.merge(wins_17_18, left_on='abbreviation', right_on='abbreviation')
stats_17_18 = stats_17_18.assign(Season=['2017-2018'] * 30)
stats_17_18.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
all_df = [stats_17_18, stats_18_19, stats_19_20]

all_df = pd.concat(all_df).reset_index(drop=True)

all_df.head()
# Out:
#   abbreviation  assists  blocks  defensive_rebounds  field_goal_attempts  \
# 0          GSW     2402     612                2877                 6981
# 1          HOU     1767     392                2825                 6906
# 2          NOP     2195     485                2924                 7241
# 3          TOR     1995     500                2807                 7169
# 4          CLE     1916     312                2761                 6950
#
#    field_goal_percentage  field_goals  free_throw_attempts  \
# 0                  0.503         3509                 1668
# 1                  0.460         3174                 2061
# 2                  0.483         3500                 1716
# 3                  0.472         3383                 1790
# 4                  0.476         3311                 1909
#
#    free_throw_percentage  free_throws  ...  three_point_field_goal_attempts  \
# 0                  0.815         1360  ...                             2370
# 1                  0.781         1609  ...                             3470
# 2                  0.772         1324  ...                             2312
# 3                  0.794         1422  ...                             2705
# 4                  0.779         1488  ...                             2636
#
#    three_point_field_goal_percentage three_point_field_goals  total_rebounds  \
# 0                              0.391                     926            3568
# 1                              0.362                    1256            3564
# 2                              0.362                     837            3636
# 3                              0.358                     968            3607
# 4                              0.372                     981            3455
#
#    turnovers  two_point_field_goal_attempts  two_point_field_goal_percentage  \
# 0       1267                           4611                            0.560
# 1       1135                           3436                            0.558
# 2       1223                           4929                            0.540
# 3       1095                           4464                            0.541
# 4       1126                           4314                            0.540
#
#    two_point_field_goals   W     Season
# 0                   2583  58  2017-2018
# 1                   1918  65  2017-2018
# 2                   2663  48  2017-2018
# 3                   2415  59  2017-2018
# 4                   2330  50  2017-2018
#
# [5 rows x 49 columns]

# %%
# Assign the data to X and y

X = all_df[["abbreviation","Season","assists", 'defensive_rebounds','field_goal_percentage','field_goals','opp_assists',
                        'opp_blocks','opp_defensive_rebounds', 'opp_field_goal_percentage','opp_points',
                        'opp_three_point_field_goal_percentage','opp_total_rebounds','opp_two_point_field_goal_percentage',
                        'points', 'three_point_field_goal_percentage', 'total_rebounds','two_point_field_goal_percentage']].set_index(['abbreviation', 'Season'])
y = all_df["W"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (90, 16) (90, 1)

# %%
# Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_test
# Out:
#                         assists  defensive_rebounds  field_goal_percentage  \
# abbreviation Season
# LAC          2017-2018     1832                2766                  0.471
# DET          2018-2019     1845                2752                  0.440
# CHO          2018-2019     1905                2778                  0.448
# BOS          2017-2018     1842                2878                  0.450
# BRK          2019-2020     1539                2409                  0.444
# PHI          2019-2020     1682                2282                  0.465
# SAS          2019-2020     1546                2244                  0.470
# DEN          2017-2018     2059                2748                  0.470
# ORL          2019-2020     1559                2220                  0.442
# OKC          2018-2019     1917                2911                  0.454
# CLE          2017-2018     1916                2761                  0.476
# DAL          2019-2020     1640                2438                  0.462
# NYK          2019-2020     1456                2274                  0.447
# DAL          2017-2018     1858                2717                  0.444
# BOS          2018-2019     2155                2849                  0.465
# MEM          2017-2018     1767                2544                  0.444
# LAL          2019-2020     1630                2239                  0.485
# UTA          2019-2020     1419                2320                  0.475
# ATL          2017-2018     1946                2693                  0.446
# DET          2017-2018     1868                2756                  0.450
# WAS          2019-2020     1621                2024                  0.461
# HOU          2019-2020     1375                2212                  0.454
# MIA          2018-2019     1991                2879                  0.450
#
#                         field_goals  opp_assists  opp_blocks  \
# abbreviation Season
# LAC          2017-2018         3302         2015         462
# DET          2018-2019         3185         1940         419
# CHO          2018-2019         3297         2133         492
# BOS          2017-2018         3141         1744         364
# BRK          2019-2020         2558         1436         342
# PHI          2019-2020         2651         1475         251
# SAS          2019-2020         2649         1621         275
# DEN          2017-2018         3338         2028         391
# ORL          2019-2020         2550         1591         312
# OKC          2018-2019         3497         2039         415
# CLE          2017-2018         3311         2122         340
# DAL          2019-2020         2787         1592         269
# NYK          2019-2020         2638         1605         333
# DAL          2017-2018         3128         1929         369
# BOS          2018-2019         3451         1940         317
# MEM          2017-2018         3013         1816         421
# LAL          2019-2020         2704         1464         235
# UTA          2019-2020         2569         1354         292
# ATL          2017-2018         3130         2137         453
# DET          2017-2018         3208         2064         398
# WAS          2019-2020         2682         1618         323
# HOU          2019-2020         2632         1619         315
# MIA          2018-2019         3251         1913         389
#
#                         opp_defensive_rebounds  opp_field_goal_percentage  \
# abbreviation Season
# LAC          2017-2018                    2706                      0.458
# DET          2018-2019                    2834                      0.469
# CHO          2018-2019                    2931                      0.470
# BOS          2017-2018                    2804                      0.440
# BRK          2019-2020                    2254                      0.442
# PHI          2019-2020                    2166                      0.462
# SAS          2019-2020                    2287                      0.469
# DEN          2017-2018                    2613                      0.476
# ORL          2019-2020                    2339                      0.463
# OKC          2018-2019                    2936                      0.460
# CLE          2017-2018                    2766                      0.474
# DAL          2019-2020                    2324                      0.454
# NYK          2019-2020                    2284                      0.463
# DAL          2017-2018                    3027                      0.469
# BOS          2018-2019                    2912                      0.448
# MEM          2017-2018                    2703                      0.462
# LAL          2019-2020                    2049                      0.444
# UTA          2019-2020                    2110                      0.452
# ATL          2017-2018                    2785                      0.469
# DET          2017-2018                    2833                      0.459
# WAS          2019-2020                    2282                      0.490
# HOU          2019-2020                    2299                      0.461
# MIA          2018-2019                    2792                      0.441
#
#                         opp_points  opp_three_point_field_goal_percentage  \
# abbreviation Season
# LAC          2017-2018        8934                                  0.356
# DET          2018-2019        8798                                  0.345
# CHO          2018-2019        9171                                  0.361
# BOS          2017-2018        8235                                  0.339
# BRK          2019-2020        7130                                  0.350
# PHI          2019-2020        6979                                  0.354
# SAS          2019-2020        7240                                  0.376
# DEN          2017-2018        8899                                  0.378
# ORL          2019-2020        6977                                  0.370
# OKC          2018-2019        9108                                  0.356
# CLE          2017-2018        9014                                  0.368
# DAL          2019-2020        7391                                  0.345
# NYK          2019-2020        7409                                  0.381
# DAL          2017-2018        8639                                  0.363
# BOS          2018-2019        8852                                  0.344
# MEM          2017-2018        8654                                  0.368
# LAL          2019-2020        6736                                  0.342
# UTA          2019-2020        6903                                  0.351
# ATL          2017-2018        8922                                  0.377
# DET          2017-2018        8521                                  0.359
# WAS          2019-2020        7658                                  0.378
# HOU          2019-2020        7320                                  0.348
# MIA          2018-2019        8687                                  0.358
#
#                         opp_total_rebounds  \
# abbreviation Season
# LAC          2017-2018                3577
# DET          2018-2019                3581
# CHO          2018-2019                3756
# BOS          2017-2018                3595
# BRK          2019-2020                2942
# PHI          2019-2020                2722
# SAS          2019-2020                2877
# DEN          2017-2018                3413
# ORL          2019-2020                2930
# OKC          2018-2019                3747
# CLE          2017-2018                3578
# DAL          2019-2020                3037
# NYK          2019-2020                2916
# DAL          2017-2018                3752
# BOS          2018-2019                3764
# MEM          2017-2018                3485
# LAL          2019-2020                2665
# UTA          2019-2020                2726
# ATL          2017-2018                3626
# DET          2017-2018                3589
# WAS          2019-2020                2962
# HOU          2019-2020                3011
# MIA          2018-2019                3623
#
#                         opp_two_point_field_goal_percentage  points  \
# abbreviation Season
# LAC          2017-2018                                0.512    8937
# DET          2018-2019                                0.530    8778
# CHO          2018-2019                                0.536    9081
# BOS          2017-2018                                0.488    8529
# BRK          2019-2020                                0.496    7089
# PHI          2019-2020                                0.518    7123
# SAS          2019-2020                                0.528    7129
# DEN          2017-2018                                0.525    9020
# ORL          2019-2020                                0.522    6914
# OKC          2018-2019                                0.517    9387
# CLE          2017-2018                                0.533    9091
# DAL          2019-2020                                0.520    7796
# NYK          2019-2020                                0.520    6983
# DAL          2017-2018                                0.526    8390
# BOS          2018-2019                                0.513    9216
# MEM          2017-2018                                0.516    8145
# LAL          2019-2020                                0.506    7203
# UTA          2019-2020                                0.507    7106
# ATL          2017-2018                                0.520    8475
# DET          2017-2018                                0.515    8509
# WAS          2019-2020                                0.557    7399
# HOU          2019-2020                                0.532    7560
# MIA          2018-2019                                0.493    8668
#
#                         three_point_field_goal_percentage  total_rebounds  \
# abbreviation Season
# LAC          2017-2018                              0.354            3598
# DET          2018-2019                              0.348            3688
# CHO          2018-2019                              0.351            3592
# BOS          2017-2018                              0.377            3645
# BRK          2019-2020                              0.340            3103
# PHI          2019-2020                              0.362            2955
# SAS          2019-2020                              0.371            2799
# DEN          2017-2018                              0.371            3650
# ORL          2019-2020                              0.341            2894
# OKC          2018-2019                              0.348            3942
# CLE          2017-2018                              0.372            3455
# DAL          2019-2020                              0.369            3150
# NYK          2019-2020                              0.337            3069
# DAL          2017-2018                              0.360            3383
# BOS          2018-2019                              0.365            3653
# MEM          2017-2018                              0.352            3323
# LAL          2019-2020                              0.355            2907
# UTA          2019-2020                              0.383            2886
# ATL          2017-2018                              0.360            3436
# DET          2017-2018                              0.373            3586
# WAS          2019-2020                              0.372            2668
# HOU          2019-2020                              0.348            2875
# MIA          2018-2019                              0.349            3800
#
#                         two_point_field_goal_percentage
# abbreviation Season
# LAC          2017-2018                            0.525
# DET          2018-2019                            0.500
# CHO          2018-2019                            0.507
# BOS          2017-2018                            0.491
# BRK          2019-2020                            0.519
# PHI          2019-2020                            0.523
# SAS          2019-2020                            0.517
# DEN          2017-2018                            0.525
# ORL          2019-2020                            0.498
# OKC          2018-2019                            0.510
# CLE          2017-2018                            0.540
# DAL          2019-2020                            0.542
# NYK          2019-2020                            0.499
# DAL          2017-2018                            0.496
# BOS          2018-2019                            0.527
# MEM          2017-2018                            0.486
# LAL          2019-2020                            0.556
# UTA          2019-2020                            0.537
# ATL          2017-2018                            0.495
# DET          2017-2018                            0.488
# WAS          2019-2020                            0.511
# HOU          2019-2020                            0.554
# MIA          2018-2019                            0.509

# %%
# Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
predictions = predictions.flatten()


MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")


lin_reg = pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()})

X_test.reset_index(inplace = True)

df_out = pd.merge(X_test, lin_reg, how = 'left',left_index = True, right_index = True)

df_out = df_out.loc[:,['Season', 'abbreviation', 'Prediction', 'Actual']]
df_out
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5acb5d6b733f> in <module>
#       7 model.fit(X_train, y_train)
#       8
# ----> 9 predictions = model.predict(X_test)
#      10 predictions = predictions.flatten()
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'LAC'

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
predictions = model.predict(X_test)
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="2017-2020 Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e6c0222fefea> in <module>
#       1 # Make predictions using a fitted model
#       2 # Plot the difference between the model predicted values and actual y values, versus the model predicted values
# ----> 3 predictions = model.predict(X_test)
#       4 model.fit(X_train, y_train)
#       5 plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="2017-2020 Training Data")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'LAC'

# %%
# LASSO model

from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train, y_train)

predictions = lasso.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = lasso.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()

# %%
# Ridge model

from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train, y_train)

predictions = ridge.predict(X_test)
predictions = predictions.flatten()

y_test = y_test.flatten()

MSE = mean_squared_error(y_test, predictions)
r2 = ridge.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test}).reset_index(drop=True).head()

# %%
# ElasticNet model

from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train, y_train)

predictions = elasticnet.predict(X_test)

MSE = mean_squared_error(y_test, predictions)
r2 = elasticnet.score(X_test, y_test)

print(f"MSE: {MSE}, R2: {r2}")

pd.DataFrame({"Prediction": np.round(predictions , 2), "Actual": y_test.ravel()}).reset_index(drop=True).head()
